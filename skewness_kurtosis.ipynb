# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
height_weight_data=pd.read_csv("500_Person_Gender_Height_Weight_Index.csv")

# %%
height_weight_data.head()
# Out:
#    Gender  Height  Weight
# 0    Male     174      96
# 1    Male     189      87
# 2  Female     185     110
# 3  Female     195     104
# 4    Male     149      61

# %%
height_weight_data.drop(columns=['Index'],inplace=True)

# %%
height_weight_data[['Height']].plot(kind='kde',title='height',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'height'}, ylabel='Density'>

# %%
height_weight_data[['Weight']].plot(kind='kde',title='weight',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'weight'}, ylabel='Density'>

# %%
height_weight_data[['Height']].skew()
# Out:
# Height   -0.121914
# dtype: float64

# %%
height_weight_data[['Weight']].skew()
# Out:
# Weight   -0.037692
# dtype: float64

# %%
height_weight_data[['Height']].kurtosis()
# Out:
# Height   -1.119671
# dtype: float64

# %%
height_weight_data[['Weight']].kurtosis()
# Out:
# Weight   -1.197325
# dtype: float64

# %%
ListOfSeries=[pd.Series(['Male',401,304],index=height_weight_data.columns),
             pd.Series(['Male',658,372],index=height_weight_data.columns),
             pd.Series(['Male',200,411],index=height_weight_data.columns),
             pd.Series(['Male',203,391],index=height_weight_data.columns),
             pd.Series(['Male',772,211],index=height_weight_data.columns),
             pd.Series(['Male',881,204],index=height_weight_data.columns)]

# %%
height_weight_updated=height_weight_data.append(ListOfSeries,ignore_index=True)

# %%
height_weight_updated.tail()
# Out:
#     Gender  Height  Weight
# 501   Male     658     372
# 502   Male     200     411
# 503   Male     203     391
# 504   Male     772     211
# 505   Male     881     204

# %%
height_weight_updated[['Height']].plot(kind='hist',title='height',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'height'}, ylabel='Frequency'>

# %%
height_weight_updated[['Height']].plot(kind='kde',title='height',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'height'}, ylabel='Density'>

# %%
height_weight_updated[['Weight']].plot(kind='hist',title='weight',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'weight'}, ylabel='Frequency'>

# %%
height_weight_updated[['Weight']].plot(kind='kde',title='weight',figsize=(8,5))
# Out:
# <AxesSubplot:title={'center':'weight'}, ylabel='Density'>

# %%
height_weight_updated[['Weight']].skew()
# Out:
# Weight    2.210363
# dtype: float64

# %%
height_weight_updated[['Height']].skew()
# Out:
# Height    10.666499
# dtype: float64
